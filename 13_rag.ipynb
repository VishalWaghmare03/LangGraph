# %%
! pip install langchain langchain-openai langchain-community langgraph python-dotenv faiss-cpu pypdf
# Out:
# Requirement already satisfied: langchain in ./LG/lg/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: langchain-openai in ./LG/lg/lib/python3.10/site-packages (1.1.6)
# Requirement already satisfied: langchain-community in ./LG/lg/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: langgraph in ./LG/lg/lib/python3.10/site-packages (1.0.5)
# Requirement already satisfied: python-dotenv in ./LG/lg/lib/python3.10/site-packages (1.2.1)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting pypdf
#   Downloading pypdf-6.6.0-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.0/329.0 kB 217.9 kB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./LG/lg/lib/python3.10/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in ./LG/lg/lib/python3.10/site-packages (from langchain) (1.2.5)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in ./LG/lg/lib/python3.10/site-packages (from langchain-openai) (2.14.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (0.5.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: numpy>=1.26.2 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./LG/lg/lib/python3.10/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in ./LG/lg/lib/python3.10/site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in ./LG/lg/lib/python3.10/site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: xxhash>=3.5.0 in ./LG/lg/lib/python3.10/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in ./LG/lg/lib/python3.10/site-packages (from langgraph) (0.3.1)
# Requirement already satisfied: packaging in ./LG/lg/lib/python3.10/site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: typing_extensions>=4.0 in ./LG/lg/lib/python3.10/site-packages (from pypdf) (4.15.0)
# Requirement already satisfied: attrs>=17.3.0 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: aiosignal>=1.4.0 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./LG/lg/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./LG/lg/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./LG/lg/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./LG/lg/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./LG/lg/lib/python3.10/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: orjson>=3.10.1 in ./LG/lg/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: httpx>=0.25.2 in ./LG/lg/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: zstandard>=0.23.0 in ./LG/lg/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./LG/lg/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: tqdm>4 in ./LG/lg/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./LG/lg/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./LG/lg/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: sniffio in ./LG/lg/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./LG/lg/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./LG/lg/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./LG/lg/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./LG/lg/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./LG/lg/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.11.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./LG/lg/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./LG/lg/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Requirement already satisfied: idna<4,>=2.5 in ./LG/lg/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: greenlet>=1 in ./LG/lg/lib/python3.10/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: regex>=2022.1.18 in ./LG/lg/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./LG/lg/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: httpcore==1.* in ./LG/lg/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./LG/lg/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./LG/lg/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./LG/lg/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Installing collected packages: pypdf, faiss-cpu
# Successfully installed faiss-cpu-1.13.2 pypdf-6.6.0
#
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.tools import tool
from langgraph.graph import StateGraph, START
from typing import Annotated, TypedDict
from langgraph.graph.message import add_messages
from langchain_core.messages import HumanMessage, BaseMessage
from langgraph.prebuilt import ToolNode, tools_condition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from dotenv import load_dotenv
#       3 from langchain_community.document_loaders import PyPDFLoader
# ----> 4 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       5 from langchain_community.vectorstores import FAISS
#       6 from langchain_core.tools import tool
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'
